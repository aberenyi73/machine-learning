# %%
from IPython.core.debugger import set_trace
#%pdb
def add_to_life_universe_everything(x):
    set_trace()
    answer = 42
    answer += x
    return answer

add_to_life_universe_everything(12)
# Out:
# > <ipython-input-1-adff58f42905>(5)add_to_life_universe_everything()
#       3 def add_to_life_universe_everything(x):
#       4     set_trace()
# ----> 5     answer = 42
#       6     answer += x
#       7     return answer
#
# ipdb> tbreak 6
# Breakpoint 1 at <ipython-input-1-adff58f42905>:6
# ipdb> ll
#       3 def add_to_life_universe_everything(x):
#       4     set_trace()
# ----> 5     answer = 42
# 1     6     answer += x
#       7     return answer
#       8
#
# ipdb> s
# > <ipython-input-1-adff58f42905>(6)add_to_life_universe_everything()
#       4     set_trace()
#       5     answer = 42
# 1---> 6     answer += x
#       7     return answer
#       8
#
# ipdb> answer
# 42
# ipdb> s
# > <ipython-input-1-adff58f42905>(7)add_to_life_universe_everything()
#       5     answer = 42
# 1     6     answer += x
# ----> 7     return answer
#       8
#       9 add_to_life_universe_everything(12)
#
# ipdb> answer
# 54
# ipdb> p answer - 1
# 53
# ipdb> w
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/runpy.py(193)_run_module_as_main()
#     191         sys.argv[0] = mod_spec.origin
#     192     return _run_code(code, main_globals, None,
# --> 193                      "__main__", mod_spec)
#     194
#     195 def run_module(mod_name, init_globals=None,
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/runpy.py(85)_run_code()
#      83                        __package__ = pkg_name,
#      84                        __spec__ = mod_spec)
# ---> 85     exec(code, run_globals)
#      86     return run_globals
#      87
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/ipykernel_launcher.py(16)<module>()
#      12     if sys.path[0] == '':
#      13         del sys.path[0]
#      14
#      15     from ipykernel import kernelapp as app
# ---> 16     app.launch_new_instance()
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/traitlets/config/application.py(658)launch_instance()
#     656         app = cls.instance(**kwargs)
#     657         app.initialize(argv)
# --> 658         app.start()
#     659
#     660 #-----------------------------------------------------------------------------
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/ipykernel/kernelapp.py(486)start()
#     484         self.io_loop = ioloop.IOLoop.current()
#     485         try:
# --> 486             self.io_loop.start()
#     487         except KeyboardInterrupt:
#     488             pass
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/tornado/platform/asyncio.py(112)start()
#     110             self._setup_logging()
#     111             asyncio.set_event_loop(self.asyncio_loop)
# --> 112             self.asyncio_loop.run_forever()
#     113         finally:
#     114             asyncio.set_event_loop(old_loop)
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/asyncio/base_events.py(422)run_forever()
#     420             events._set_running_loop(self)
#     421             while True:
# --> 422                 self._run_once()
#     423                 if self._stopping:
#     424                     break
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/asyncio/base_events.py(1432)_run_once()
#    1430                     self._current_handle = None
#    1431             else:
# -> 1432                 handle._run()
#    1433         handle = None  # Needed to break cycles when an exception occurs.
#    1434
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/asyncio/events.py(145)_run()
#     143     def _run(self):
#     144         try:
# --> 145             self._callback(*self._args)
#     146         except Exception as exc:
#     147             cb = _format_callback_source(self._callback, self._args)
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/tornado/platform/asyncio.py(102)_handle_events()
#     100     def _handle_events(self, fd, events):
#     101         fileobj, handler_func = self.handlers[fd]
# --> 102         handler_func(fileobj, events)
#     103
#     104     def start(self):
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/tornado/stack_context.py(276)null_wrapper()
#     274                 current_state = _state.contexts
#     275                 _state.contexts = cap_contexts[0]
# --> 276                 return fn(*args, **kwargs)
#     277             finally:
#     278                 _state.contexts = current_state
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py(450)_handle_events()
#     448             # dispatch events:
#     449             if zmq_events & zmq.POLLIN and self.receiving():
# --> 450                 self._handle_recv()
#     451                 if not self.socket:
#     452                     return
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py(480)_handle_recv()
#     478             if self._recv_callback:
#     479                 callback = self._recv_callback
# --> 480                 self._run_callback(callback, msg)
#     481
#     482
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py(432)_run_callback()
#     430             # inside our blanket exception handler rather than outside.
#     431             with stack_context.NullContext():
# --> 432                 callback(*args, **kwargs)
#     433         except:
#     434             gen_log.error("Uncaught exception in ZMQStream callback",
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/tornado/stack_context.py(276)null_wrapper()
#     274                 current_state = _state.contexts
#     275                 _state.contexts = cap_contexts[0]
# --> 276                 return fn(*args, **kwargs)
#     277             finally:
#     278                 _state.contexts = current_state
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/ipykernel/kernelbase.py(283)dispatcher()
#     281         def make_dispatcher(stream):
#     282             def dispatcher(msg):
# --> 283                 return self.dispatch_shell(stream, msg)
#     284             return dispatcher
#     285
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/ipykernel/kernelbase.py(233)dispatch_shell()
#     231             self.pre_handler_hook()
#     232             try:
# --> 233                 handler(stream, idents, msg)
#     234             except Exception:
#     235                 self.log.error("Exception in message handler:", exc_info=True)
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/ipykernel/kernelbase.py(399)execute_request()
#     397
#     398         reply_content = self.do_execute(code, silent, store_history,
# --> 399                                         user_expressions, allow_stdin)
#     400
#     401         # Flush output before sending the reply.
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/ipykernel/ipkernel.py(208)do_execute()
#     206         reply_content = {}
#     207         try:
# --> 208             res = shell.run_cell(code, store_history=store_history, silent=silent)
#     209         finally:
#     210             self._restore_input()
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/ipykernel/zmqshell.py(537)run_cell()
#     535     def run_cell(self, *args, **kwargs):
#     536         self._last_traceback = None
# --> 537         return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#     538
#     539     def _showtraceback(self, etype, evalue, stb):
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py(2728)run_cell()
#    2726                 interactivity = "none" if silent else self.ast_node_interactivity
#    2727                 has_raised = self.run_ast_nodes(code_ast.body, cell_name,
# -> 2728                    interactivity=interactivity, compiler=compiler, result=result)
#    2729
#    2730                 self.last_execution_succeeded = not has_raised
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py(2856)run_ast_nodes()
#    2854                 mod = ast.Interactive([node])
#    2855                 code = compiler(mod, cell_name, "single")
# -> 2856                 if self.run_code(code, result):
#    2857                     return True
#    2858
#
#   /Users/aberenyi/anaconda2/envs/Py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py(2910)run_code()
#    2908                 self.hooks.pre_run_code_hook()
#    2909                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2910                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2911             finally:
#    2912                 # Reset our crash handler in place
#
#   <ipython-input-1-adff58f42905>(9)<module>()
#       5     answer = 42
# 1     6     answer += x
#       7     return answer
#       8
# ----> 9 add_to_life_universe_everything(12)
#
# > <ipython-input-1-adff58f42905>(7)add_to_life_universe_everything()
#       5     answer = 42
# 1     6     answer += x
# ----> 7     return answer
#       8
#       9 add_to_life_universe_everything(12)
# ipdb> u
# > <ipython-input-1-adff58f42905>(9)<module>()
#       5     answer = 42
# 1     6     answer += x
#       7     return answer
#       8
# ----> 9 add_to_life_universe_everything(12)
